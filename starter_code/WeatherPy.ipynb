# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 614

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
base_url = f"https://api.openweathermap.org/data/2.5/weather?&appid={weather_api_key}&units=metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = f"{base_url}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = city_weather = requests.get(city_url, city).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nemuro
# Processing Record 2 of Set 1 | obu
# Processing Record 3 of Set 1 | crane
# Processing Record 4 of Set 1 | blackmans bay
# Processing Record 5 of Set 1 | west island
# Processing Record 6 of Set 1 | keflavik
# Processing Record 7 of Set 1 | enewetak
# Processing Record 8 of Set 1 | edinburgh of the seven seas
# Processing Record 9 of Set 1 | lompoc
# Processing Record 10 of Set 1 | mikhaylov
# Processing Record 11 of Set 1 | natchitoches
# Processing Record 12 of Set 1 | beloyarskiy
# Processing Record 13 of Set 1 | okoneshnikovo
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | bonthe
# Processing Record 16 of Set 1 | papatowai
# Processing Record 17 of Set 1 | tual
# Processing Record 18 of Set 1 | aswan
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | thompson
# Processing Record 21 of Set 1 | port-aux-francais
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | iqaluit
# Processing Record 24 of Set 1 | nakhabino
# Processing Record 25 of Set 1 | saudarkrokur
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | oruro
# Processing Record 28 of Set 1 | ilulissat
# Processing Record 29 of Set 1 | vanino
# Processing Record 30 of Set 1 | alofi
# Processing Record 31 of Set 1 | kostyantynivka
# Processing Record 32 of Set 1 | dryden
# Processing Record 33 of Set 1 | st. john's
# Processing Record 34 of Set 1 | fenoarivo atsinanana
# Processing Record 35 of Set 1 | portland
# Processing Record 36 of Set 1 | tiksi
# Processing Record 37 of Set 1 | nuku'alofa
# Processing Record 38 of Set 1 | ust-nera
# Processing Record 39 of Set 1 | atafu village
# Processing Record 40 of Set 1 | fale old settlement
# Processing Record 41 of Set 1 | bethel
# Processing Record 42 of Set 1 | puerto natales
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | santana
# Processing Record 45 of Set 1 | conception bay south
# Processing Record 46 of Set 1 | yellowknife
# Processing Record 47 of Set 1 | sinabang
# Processing Record 48 of Set 1 | pacific grove
# Processing Record 49 of Set 1 | mount gambier
# Processing Record 50 of Set 1 | grytviken
# Processing Record 1 of Set 2 | oranjemund
# Processing Record 2 of Set 2 | tofol
# Processing Record 3 of Set 2 | waitangi
# Processing Record 4 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 5 of Set 2 | posse
# Processing Record 6 of Set 2 | manga
# Processing Record 7 of Set 2 | hanzhong
# Processing Record 8 of Set 2 | arvika
# Processing Record 9 of Set 2 | longyearbyen
# Processing Record 10 of Set 2 | east london
# Processing Record 11 of Set 2 | conde
# Processing Record 12 of Set 2 | celestun
# Processing Record 13 of Set 2 | olavarria
# Processing Record 14 of Set 2 | isafjordur
# Processing Record 15 of Set 2 | adamstown
# Processing Record 16 of Set 2 | lautoka
# Processing Record 17 of Set 2 | priyutovo
# Processing Record 18 of Set 2 | haiku-pauwela
# Processing Record 19 of Set 2 | stanley
# Processing Record 20 of Set 2 | kone
# Processing Record 21 of Set 2 | scarborough
# Processing Record 22 of Set 2 | aasiaat
# Processing Record 23 of Set 2 | fort mcmurray
# Processing Record 24 of Set 2 | tsiombe
# Processing Record 25 of Set 2 | bredasdorp
# Processing Record 26 of Set 2 | dosso
# Processing Record 27 of Set 2 | chulym
# Processing Record 28 of Set 2 | olonkinbyen
# Processing Record 29 of Set 2 | margaret river
# Processing Record 30 of Set 2 | homer
# Processing Record 31 of Set 2 | mahanoro
# Processing Record 32 of Set 2 | new norfolk
# Processing Record 33 of Set 2 | beihuaidian
# Processing Record 34 of Set 2 | kapuskasing
# Processing Record 35 of Set 2 | kailua-kona
# Processing Record 36 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 37 of Set 2 | afaahiti
# Processing Record 38 of Set 2 | cobija
# Processing Record 39 of Set 2 | dunedin
# Processing Record 40 of Set 2 | dhidhdhoo
# Processing Record 41 of Set 2 | howard springs
# Processing Record 42 of Set 2 | kotido
# Processing Record 43 of Set 2 | port mathurin
# Processing Record 44 of Set 2 | codrington
# Processing Record 45 of Set 2 | dalnegorsk
# Processing Record 46 of Set 2 | albufeira
# Processing Record 47 of Set 2 | punta arenas
# Processing Record 48 of Set 2 | gueltat zemmour
# City not found. Skipping...
# Processing Record 49 of Set 2 | nikshahr
# City not found. Skipping...
# Processing Record 50 of Set 2 | savanna-la-mar
# Processing Record 1 of Set 3 | hammerfest
# Processing Record 2 of Set 3 | tongliao
# Processing Record 3 of Set 3 | iskateley
# Processing Record 4 of Set 3 | buka
# Processing Record 5 of Set 3 | cockburn town
# Processing Record 6 of Set 3 | lyantor
# Processing Record 7 of Set 3 | katsuura
# Processing Record 8 of Set 3 | nyaungdon
# Processing Record 9 of Set 3 | whitehorse
# Processing Record 10 of Set 3 | bayganin
# Processing Record 11 of Set 3 | korla
# Processing Record 12 of Set 3 | hawaiian paradise park
# Processing Record 13 of Set 3 | collie
# Processing Record 14 of Set 3 | iranshahr
# Processing Record 15 of Set 3 | touros
# Processing Record 16 of Set 3 | sovetskiy
# Processing Record 17 of Set 3 | cargados carajos
# City not found. Skipping...
# Processing Record 18 of Set 3 | badger
# Processing Record 19 of Set 3 | invercargill
# Processing Record 20 of Set 3 | boa vista
# Processing Record 21 of Set 3 | saint-denis
# Processing Record 22 of Set 3 | camapua
# Processing Record 23 of Set 3 | klyuchi
# Processing Record 24 of Set 3 | cabo san lucas
# Processing Record 25 of Set 3 | kyren
# Processing Record 26 of Set 3 | newnham
# Processing Record 27 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 28 of Set 3 | alice springs
# Processing Record 29 of Set 3 | gadzhiyevo
# Processing Record 30 of Set 3 | ouellah
# City not found. Skipping...
# Processing Record 31 of Set 3 | argo
# Processing Record 32 of Set 3 | port elizabeth
# Processing Record 33 of Set 3 | prince rupert
# Processing Record 34 of Set 3 | siwa oasis
# Processing Record 35 of Set 3 | holualoa
# Processing Record 36 of Set 3 | ksar el kebir
# Processing Record 37 of Set 3 | port augusta
# Processing Record 38 of Set 3 | sa'dah
# Processing Record 39 of Set 3 | konarka
# Processing Record 40 of Set 3 | balykshi
# Processing Record 41 of Set 3 | rosalie
# Processing Record 42 of Set 3 | romilly-sur-seine
# Processing Record 43 of Set 3 | mapastepec
# Processing Record 44 of Set 3 | ta`u
# Processing Record 45 of Set 3 | prado
# Processing Record 46 of Set 3 | saint-philippe
# Processing Record 47 of Set 3 | faaa
# Processing Record 48 of Set 3 | salinas
# Processing Record 49 of Set 3 | kingston
# Processing Record 50 of Set 3 | q'vareli
# Processing Record 1 of Set 4 | ribeira grande
# Processing Record 2 of Set 4 | vrnograc
# Processing Record 3 of Set 4 | oodweyne
# Processing Record 4 of Set 4 | shimokizukuri
# Processing Record 5 of Set 4 | anadyr
# Processing Record 6 of Set 4 | sitka
# Processing Record 7 of Set 4 | san antonio de pale
# Processing Record 8 of Set 4 | ratnagiri
# Processing Record 9 of Set 4 | reggane
# Processing Record 10 of Set 4 | mujiayingzi
# Processing Record 11 of Set 4 | yanbu
# Processing Record 12 of Set 4 | fada n'gourma
# Processing Record 13 of Set 4 | la rioja
# Processing Record 14 of Set 4 | hadibu
# Processing Record 15 of Set 4 | karaton
# Processing Record 16 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 17 of Set 4 | torghay
# Processing Record 18 of Set 4 | kachug
# Processing Record 19 of Set 4 | mejit
# Processing Record 20 of Set 4 | goz beida
# Processing Record 21 of Set 4 | faya-largeau
# Processing Record 22 of Set 4 | udachny
# Processing Record 23 of Set 4 | port alfred
# Processing Record 24 of Set 4 | ushuaia
# Processing Record 25 of Set 4 | westport
# Processing Record 26 of Set 4 | ujszasz
# Processing Record 27 of Set 4 | bikenibeu village
# Processing Record 28 of Set 4 | el calafate
# Processing Record 29 of Set 4 | micheweni
# Processing Record 30 of Set 4 | ahau
# City not found. Skipping...
# Processing Record 31 of Set 4 | casper
# Processing Record 32 of Set 4 | sokcho
# Processing Record 33 of Set 4 | nizhyn
# Processing Record 34 of Set 4 | gazojak
# Processing Record 35 of Set 4 | hermanus
# Processing Record 36 of Set 4 | port hueneme
# Processing Record 37 of Set 4 | isiolo
# Processing Record 38 of Set 4 | harper
# Processing Record 39 of Set 4 | ulladulla
# Processing Record 40 of Set 4 | mermoz boabab
# Processing Record 41 of Set 4 | roscommon
# Processing Record 42 of Set 4 | gatton
# Processing Record 43 of Set 4 | lapinlahti
# Processing Record 44 of Set 4 | kamen'-na-obi
# Processing Record 45 of Set 4 | jayapura
# Processing Record 46 of Set 4 | remire-montjoly
# Processing Record 47 of Set 4 | santa maria do para
# Processing Record 48 of Set 4 | velyka lepetykha
# Processing Record 49 of Set 4 | brookings
# Processing Record 50 of Set 4 | lincoln
# Processing Record 1 of Set 5 | bardai
# Processing Record 2 of Set 5 | lekeitio
# Processing Record 3 of Set 5 | alesund
# Processing Record 4 of Set 5 | belyy yar
# Processing Record 5 of Set 5 | baise city
# Processing Record 6 of Set 5 | aku
# Processing Record 7 of Set 5 | bollnas
# Processing Record 8 of Set 5 | kinkala
# Processing Record 9 of Set 5 | tolanaro
# Processing Record 10 of Set 5 | utrik
# Processing Record 11 of Set 5 | orcopampa
# Processing Record 12 of Set 5 | mandalgovi
# Processing Record 13 of Set 5 | mounana
# Processing Record 14 of Set 5 | carnarvon
# Processing Record 15 of Set 5 | berani
# Processing Record 16 of Set 5 | thunder bay
# Processing Record 17 of Set 5 | kodiak
# Processing Record 18 of Set 5 | raja
# Processing Record 19 of Set 5 | sarangani
# Processing Record 20 of Set 5 | malaryta
# Processing Record 21 of Set 5 | ravar
# Processing Record 22 of Set 5 | santa cruz
# Processing Record 23 of Set 5 | saipan
# Processing Record 24 of Set 5 | maun
# Processing Record 25 of Set 5 | george town
# Processing Record 26 of Set 5 | chonchi
# Processing Record 27 of Set 5 | khandyga
# Processing Record 28 of Set 5 | barah
# Processing Record 29 of Set 5 | krylovskaya
# Processing Record 30 of Set 5 | bhopalwala
# Processing Record 31 of Set 5 | tommot
# Processing Record 32 of Set 5 | mount isa
# Processing Record 33 of Set 5 | grand gaube
# Processing Record 34 of Set 5 | aykhal
# Processing Record 35 of Set 5 | puerto leguizamo
# Processing Record 36 of Set 5 | wailua homesteads
# Processing Record 37 of Set 5 | san jose village
# City not found. Skipping...
# Processing Record 38 of Set 5 | surgut
# Processing Record 39 of Set 5 | colonia
# Processing Record 40 of Set 5 | omdurman
# Processing Record 41 of Set 5 | merritt
# Processing Record 42 of Set 5 | tomakomai
# Processing Record 43 of Set 5 | vilyuchinsk
# Processing Record 44 of Set 5 | bilibino
# Processing Record 45 of Set 5 | west bay
# Processing Record 46 of Set 5 | kristiansund
# Processing Record 47 of Set 5 | manokwari
# Processing Record 48 of Set 5 | hasaki
# Processing Record 49 of Set 5 | georgetown
# Processing Record 50 of Set 5 | tirumullaivasal
# Processing Record 1 of Set 6 | hamilton
# Processing Record 2 of Set 6 | slave lake
# Processing Record 3 of Set 6 | ketchikan
# Processing Record 4 of Set 6 | lakatoro
# Processing Record 5 of Set 6 | luena
# Processing Record 6 of Set 6 | katsuren-haebaru
# Processing Record 7 of Set 6 | minas de marcona
# Processing Record 8 of Set 6 | yaren
# Processing Record 9 of Set 6 | gotsucho
# Processing Record 10 of Set 6 | gamba
# Processing Record 11 of Set 6 | hovd
# Processing Record 12 of Set 6 | howrah
# Processing Record 13 of Set 6 | turpan
# Processing Record 14 of Set 6 | kourou
# Processing Record 15 of Set 6 | sept-iles
# Processing Record 16 of Set 6 | mugia
# Processing Record 17 of Set 6 | falesti
# Processing Record 18 of Set 6 | talnakh
# Processing Record 19 of Set 6 | arta
# Processing Record 20 of Set 6 | bagli
# Processing Record 21 of Set 6 | napoleon
# Processing Record 22 of Set 6 | nikol'sk
# Processing Record 23 of Set 6 | tabou
# Processing Record 24 of Set 6 | machico
# Processing Record 25 of Set 6 | kemise
# Processing Record 26 of Set 6 | kisarazu
# Processing Record 27 of Set 6 | papao
# Processing Record 28 of Set 6 | kochkor-ata
# Processing Record 29 of Set 6 | nova sintra
# Processing Record 30 of Set 6 | plettenberg bay
# Processing Record 31 of Set 6 | lihue
# Processing Record 32 of Set 6 | san lawrenz
# Processing Record 33 of Set 6 | ghormach
# Processing Record 34 of Set 6 | kuusamo
# Processing Record 35 of Set 6 | armavir
# Processing Record 36 of Set 6 | ponta delgada
# Processing Record 37 of Set 6 | barcelos
# Processing Record 38 of Set 6 | ust'-ilimsk
# Processing Record 39 of Set 6 | tazovsky
# Processing Record 40 of Set 6 | sinop
# Processing Record 41 of Set 6 | kuanda
# Processing Record 42 of Set 6 | polyarnyy
# Processing Record 43 of Set 6 | maneromango
# Processing Record 44 of Set 6 | muang phonsavan
# Processing Record 45 of Set 6 | constantia
# Processing Record 46 of Set 6 | bessemer
# Processing Record 47 of Set 6 | flin flon
# Processing Record 48 of Set 6 | gao
# Processing Record 49 of Set 6 | kataragama
# City not found. Skipping...
# Processing Record 50 of Set 6 | yangiqo'rg'on
# Processing Record 1 of Set 7 | nakamura
# Processing Record 2 of Set 7 | coxen hole
# Processing Record 3 of Set 7 | buta
# Processing Record 4 of Set 7 | college
# Processing Record 5 of Set 7 | luderitz
# Processing Record 6 of Set 7 | elk city
# Processing Record 7 of Set 7 | lysyye gory
# Processing Record 8 of Set 7 | forked river
# Processing Record 9 of Set 7 | gizo
# Processing Record 10 of Set 7 | zaragoza
# Processing Record 11 of Set 7 | dili
# Processing Record 12 of Set 7 | nili
# Processing Record 13 of Set 7 | devinuwara
# City not found. Skipping...
# Processing Record 14 of Set 7 | san patricio
# Processing Record 15 of Set 7 | poronaysk
# Processing Record 16 of Set 7 | barra do corda
# Processing Record 17 of Set 7 | lebu
# Processing Record 18 of Set 7 | eastham
# Processing Record 19 of Set 7 | callao
# Processing Record 20 of Set 7 | ciudad bolivar
# Processing Record 21 of Set 7 | alo
# Processing Record 22 of Set 7 | severo-vostotchnyi bank
# Processing Record 23 of Set 7 | hotan
# Processing Record 24 of Set 7 | bismarck
# Processing Record 25 of Set 7 | tsementnyy
# Processing Record 26 of Set 7 | san fernando
# Processing Record 27 of Set 7 | jabor
# Processing Record 28 of Set 7 | kutum
# Processing Record 29 of Set 7 | venice
# Processing Record 30 of Set 7 | lianzhou
# Processing Record 31 of Set 7 | xining
# Processing Record 32 of Set 7 | ust-tsilma
# Processing Record 33 of Set 7 | nar'yan-mar
# Processing Record 34 of Set 7 | cherykaw
# Processing Record 35 of Set 7 | mbabane
# Processing Record 36 of Set 7 | uturoa
# Processing Record 37 of Set 7 | yagry
# City not found. Skipping...
# Processing Record 38 of Set 7 | montdidier
# Processing Record 39 of Set 7 | nashtarud
# City not found. Skipping...
# Processing Record 40 of Set 7 | kalmunai
# Processing Record 41 of Set 7 | miasskoye
# Processing Record 42 of Set 7 | siracusa
# Processing Record 43 of Set 7 | laojunmiao
# Processing Record 44 of Set 7 | muynoq
# Processing Record 45 of Set 7 | geraldton
# Processing Record 46 of Set 7 | makhambet
# Processing Record 47 of Set 7 | jijiga
# Processing Record 48 of Set 7 | chernyshevskiy
# Processing Record 49 of Set 7 | rabaul
# Processing Record 50 of Set 7 | san pedro pochutla
# Processing Record 1 of Set 8 | severo-yeniseyskiy
# Processing Record 2 of Set 8 | kotlas
# Processing Record 3 of Set 8 | saldanha
# Processing Record 4 of Set 8 | deir ez-zor
# Processing Record 5 of Set 8 | baharly
# Processing Record 6 of Set 8 | nadi
# Processing Record 7 of Set 8 | troitskoye
# Processing Record 8 of Set 8 | muntok
# Processing Record 9 of Set 8 | hami
# Processing Record 10 of Set 8 | lukolela
# Processing Record 11 of Set 8 | port lincoln
# Processing Record 12 of Set 8 | egilsstadir
# Processing Record 13 of Set 8 | harstad
# Processing Record 14 of Set 8 | dul'durga
# Processing Record 15 of Set 8 | sangueya
# Processing Record 16 of Set 8 | karratha
# Processing Record 17 of Set 8 | kibara
# Processing Record 18 of Set 8 | ribeira brava
# Processing Record 19 of Set 8 | stryi
# Processing Record 20 of Set 8 | khorugh
# Processing Record 21 of Set 8 | borogontsy
# Processing Record 22 of Set 8 | lethbridge
# Processing Record 23 of Set 8 | sorong
# Processing Record 24 of Set 8 | lazaro cardenas
# Processing Record 25 of Set 8 | mandla
# Processing Record 26 of Set 8 | itaituba
# Processing Record 27 of Set 8 | noshiro
# Processing Record 28 of Set 8 | conduaga
# Processing Record 29 of Set 8 | ulsteinvik
# Processing Record 30 of Set 8 | kovalam
# Processing Record 31 of Set 8 | norilsk
# Processing Record 32 of Set 8 | dorsten
# Processing Record 33 of Set 8 | quellon
# City not found. Skipping...
# Processing Record 34 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 35 of Set 8 | northam
# Processing Record 36 of Set 8 | abepura
# Processing Record 37 of Set 8 | fuxin
# Processing Record 38 of Set 8 | antsiranana
# Processing Record 39 of Set 8 | bangui
# Processing Record 40 of Set 8 | khamis mushait
# Processing Record 41 of Set 8 | kulia village
# City not found. Skipping...
# Processing Record 42 of Set 8 | tindouf
# Processing Record 43 of Set 8 | taoudenni
# Processing Record 44 of Set 8 | nichinan
# Processing Record 45 of Set 8 | miches
# Processing Record 46 of Set 8 | magdagachi
# Processing Record 47 of Set 8 | ancud
# Processing Record 48 of Set 8 | zhytomyr
# Processing Record 49 of Set 8 | jabal os saraj
# Processing Record 50 of Set 8 | kapa'a
# Processing Record 1 of Set 9 | port saint john's
# Processing Record 2 of Set 9 | mozarlandia
# Processing Record 3 of Set 9 | bridlington
# Processing Record 4 of Set 9 | la paz
# Processing Record 5 of Set 9 | bodaybo
# Processing Record 6 of Set 9 | meadow lake
# Processing Record 7 of Set 9 | as samawah
# Processing Record 8 of Set 9 | suining
# Processing Record 9 of Set 9 | ouani
# Processing Record 10 of Set 9 | nako
# Processing Record 11 of Set 9 | mount darwin
# Processing Record 12 of Set 9 | yeppoon
# Processing Record 13 of Set 9 | moyale
# Processing Record 14 of Set 9 | zango
# Processing Record 15 of Set 9 | caleta de carquin
# Processing Record 16 of Set 9 | puerto san carlos
# City not found. Skipping...
# Processing Record 17 of Set 9 | candelaria
# Processing Record 18 of Set 9 | tura
# Processing Record 19 of Set 9 | grand falls-windsor
# Processing Record 20 of Set 9 | linxia chengguanzhen
# Processing Record 21 of Set 9 | richards bay
# Processing Record 22 of Set 9 | agat village
# Processing Record 23 of Set 9 | fallon
# Processing Record 24 of Set 9 | omutninsk
# Processing Record 25 of Set 9 | buba
# Processing Record 26 of Set 9 | puerto deseado
# Processing Record 27 of Set 9 | san buenaventura
# Processing Record 28 of Set 9 | greymouth
# Processing Record 29 of Set 9 | newman
# Processing Record 30 of Set 9 | leksand
# Processing Record 31 of Set 9 | nouadhibou
# Processing Record 32 of Set 9 | moussoro
# Processing Record 33 of Set 9 | cill airne
# Processing Record 34 of Set 9 | dongyang
# Processing Record 35 of Set 9 | petrovets
# City not found. Skipping...
# Processing Record 36 of Set 9 | benguela
# Processing Record 37 of Set 9 | labytnangi
# Processing Record 38 of Set 9 | revda
# Processing Record 39 of Set 9 | ringkobing
# Processing Record 40 of Set 9 | happy valley-goose bay
# Processing Record 41 of Set 9 | jaca
# Processing Record 42 of Set 9 | ellsworth
# Processing Record 43 of Set 9 | ad dilam
# Processing Record 44 of Set 9 | west busselton
# City not found. Skipping...
# Processing Record 45 of Set 9 | la sarre
# Processing Record 46 of Set 9 | fuyang
# Processing Record 47 of Set 9 | deoband
# Processing Record 48 of Set 9 | dakhla
# Processing Record 49 of Set 9 | coquimbo
# Processing Record 50 of Set 9 | roja
# Processing Record 1 of Set 10 | shihezi
# Processing Record 2 of Set 10 | as sulayyil
# Processing Record 3 of Set 10 | vimmerby
# Processing Record 4 of Set 10 | decize
# Processing Record 5 of Set 10 | prien
# Processing Record 6 of Set 10 | north bend
# Processing Record 7 of Set 10 | igrim
# Processing Record 8 of Set 10 | leeton
# Processing Record 9 of Set 10 | nishinoomote
# Processing Record 10 of Set 10 | santa maria
# Processing Record 11 of Set 10 | tevragh zeina
# City not found. Skipping...
# Processing Record 12 of Set 10 | sovetskaya gavan'
# Processing Record 13 of Set 10 | kratie
# Processing Record 14 of Set 10 | elverum
# Processing Record 15 of Set 10 | tadine
# Processing Record 16 of Set 10 | longonjo
# Processing Record 17 of Set 10 | sao joao da barra
# Processing Record 18 of Set 10 | bamboo flat
# Processing Record 19 of Set 10 | guerrero negro
# Processing Record 20 of Set 10 | cable beach
# City not found. Skipping...
# Processing Record 21 of Set 10 | praia da vitoria
# Processing Record 22 of Set 10 | penaranda de bracamonte
# Processing Record 23 of Set 10 | dudinka
# Processing Record 24 of Set 10 | pundong
# Processing Record 25 of Set 10 | ouro preto do oeste
# Processing Record 26 of Set 10 | massaguet
# Processing Record 27 of Set 10 | cao bang
# Processing Record 28 of Set 10 | khark
# Processing Record 29 of Set 10 | chumphon
# Processing Record 30 of Set 10 | laascaanood
# Processing Record 31 of Set 10 | rockdale
# Processing Record 32 of Set 10 | port douglas
# Processing Record 33 of Set 10 | salumbar
# Processing Record 34 of Set 10 | aioun
# Processing Record 35 of Set 10 | talcahuano
# Processing Record 36 of Set 10 | mkushi
# Processing Record 37 of Set 10 | yuzhno-kurilsk
# Processing Record 38 of Set 10 | noosa heads
# Processing Record 39 of Set 10 | nenjiang
# Processing Record 40 of Set 10 | lata
# Processing Record 41 of Set 10 | magadan
# Processing Record 42 of Set 10 | pallisa
# Processing Record 43 of Set 10 | kingscliff
# Processing Record 44 of Set 10 | palikir - national government center
# Processing Record 45 of Set 10 | samraong
# Processing Record 46 of Set 10 | port glaud
# City not found. Skipping...
# Processing Record 47 of Set 10 | 'ohonua
# City not found. Skipping...
# Processing Record 48 of Set 10 | nieuw nickerie
# Processing Record 49 of Set 10 | tarakan
# Processing Record 50 of Set 10 | zangguy
# City not found. Skipping...
# Processing Record 1 of Set 11 | kavieng
# Processing Record 2 of Set 11 | verkhovazh'ye
# Processing Record 3 of Set 11 | raduzhny
# Processing Record 4 of Set 11 | rock springs
# Processing Record 5 of Set 11 | rabigh
# Processing Record 6 of Set 11 | midvagur
# Processing Record 7 of Set 11 | arraial do cabo
# Processing Record 8 of Set 11 | matehuala
# Processing Record 9 of Set 11 | yarmouth
# Processing Record 10 of Set 11 | kurumkan
# Processing Record 11 of Set 11 | sao vicente
# Processing Record 12 of Set 11 | porangatu
# Processing Record 13 of Set 11 | piura
# Processing Record 14 of Set 11 | siniscola
# Processing Record 15 of Set 11 | belmonte
# Processing Record 16 of Set 11 | fomboni
# Processing Record 17 of Set 11 | zapata
# Processing Record 18 of Set 11 | kiunga
# Processing Record 19 of Set 11 | paita
# Processing Record 20 of Set 11 | kiama
# Processing Record 21 of Set 11 | dolores
# Processing Record 22 of Set 11 | ivdel'
# Processing Record 23 of Set 11 | qaqortoq
# Processing Record 24 of Set 11 | okhotsk
# Processing Record 25 of Set 11 | lerwick
# Processing Record 26 of Set 11 | kishtwar
# Processing Record 27 of Set 11 | naantali
# Processing Record 28 of Set 11 | palmas
# Processing Record 29 of Set 11 | selfoss
# Processing Record 30 of Set 11 | arawa
# Processing Record 31 of Set 11 | puerto san jose
# Processing Record 32 of Set 11 | rukban
# City not found. Skipping...
# Processing Record 33 of Set 11 | camocim
# Processing Record 34 of Set 11 | labrador city
# Processing Record 35 of Set 11 | el tarf
# Processing Record 36 of Set 11 | mahina
# Processing Record 37 of Set 11 | meadow lakes
# Processing Record 38 of Set 11 | leninskoye
# Processing Record 39 of Set 11 | lugait
# Processing Record 40 of Set 11 | road town
# Processing Record 41 of Set 11 | valparaiso
# Processing Record 42 of Set 11 | ataq
# Processing Record 43 of Set 11 | griffith
# Processing Record 44 of Set 11 | markovo
# Processing Record 45 of Set 11 | kirillov
# Processing Record 46 of Set 11 | flying fish cove
# Processing Record 47 of Set 11 | kosciuszko national park
# City not found. Skipping...
# Processing Record 48 of Set 11 | birao
# Processing Record 49 of Set 11 | tamanrasset
# Processing Record 50 of Set 11 | potsdam
# Processing Record 1 of Set 12 | vadso
# Processing Record 2 of Set 12 | hiratacho
# Processing Record 3 of Set 12 | sao mateus do sul
# Processing Record 4 of Set 12 | pangody
# Processing Record 5 of Set 12 | susuman
# Processing Record 6 of Set 12 | qorovulbozor
# Processing Record 7 of Set 12 | sarpol-e zahab
# Processing Record 8 of Set 12 | shuangjiang
# Processing Record 9 of Set 12 | sabang
# Processing Record 10 of Set 12 | kozani
# Processing Record 11 of Set 12 | dhana
# Processing Record 12 of Set 12 | huarmey
# Processing Record 13 of Set 12 | moron
# Processing Record 14 of Set 12 | pemangkat
# Processing Record 15 of Set 12 | esperanza
# Processing Record 16 of Set 12 | tranovaho
# City not found. Skipping...
# Processing Record 17 of Set 12 | areia branca
# Processing Record 18 of Set 12 | altamira
# Processing Record 19 of Set 12 | burang
# Processing Record 20 of Set 12 | toamasina
# Processing Record 21 of Set 12 | roma
# Processing Record 22 of Set 12 | rauma
# Processing Record 23 of Set 12 | algeciras
# Processing Record 24 of Set 12 | isle of lewis
# City not found. Skipping...
# Processing Record 25 of Set 12 | camayenne
# Processing Record 26 of Set 12 | akrehamn
# Processing Record 27 of Set 12 | weining
# Processing Record 28 of Set 12 | pibor
# City not found. Skipping...
# Processing Record 29 of Set 12 | schweizer-reneke
# Processing Record 30 of Set 12 | majene
# Processing Record 31 of Set 12 | goure
# Processing Record 32 of Set 12 | beauvais
# Processing Record 33 of Set 12 | thakurgaon
# Processing Record 34 of Set 12 | tan-tan
# Processing Record 35 of Set 12 | dancu
# Processing Record 36 of Set 12 | sonsorol village
# City not found. Skipping...
# Processing Record 37 of Set 12 | barreirinhas
# Processing Record 38 of Set 12 | aberdeen
# Processing Record 39 of Set 12 | naze
# Processing Record 40 of Set 12 | chilmari
# Processing Record 41 of Set 12 | chibougamau
# Processing Record 42 of Set 12 | masons bay
# City not found. Skipping...
# Processing Record 43 of Set 12 | chinchani
# Processing Record 44 of Set 12 | bandon
# Processing Record 45 of Set 12 | sosnogorsk
# Processing Record 46 of Set 12 | preobrazheniye
# Processing Record 47 of Set 12 | lagunas
# Processing Record 48 of Set 12 | kerikeri
# Processing Record 49 of Set 12 | qamdo
# Processing Record 50 of Set 12 | elliot lake
# Processing Record 1 of Set 13 | walvis bay
# Processing Record 2 of Set 13 | takamaka
# City not found. Skipping...
# Processing Record 3 of Set 13 | christchurch
# Processing Record 4 of Set 13 | sokolac
# Processing Record 5 of Set 13 | yelizovo
# Processing Record 6 of Set 13 | cabedelo
# Processing Record 7 of Set 13 | rio pardo de minas
# Processing Record 8 of Set 13 | kapshagay
# Processing Record 9 of Set 13 | vorgashor
# Processing Record 10 of Set 13 | tambo
# Processing Record 11 of Set 13 | luanda
# Processing Record 12 of Set 13 | garoowe
# Processing Record 13 of Set 13 | marathon
# Processing Record 14 of Set 13 | la passe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          582
# Lat           582
# Lng           582
# Max Temp      582
# Humidity      582
# Cloudiness    582
# Wind Speed    582
# Country       582
# Date          582
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         nemuro  43.3236  145.5750      6.95        76          15
# 1            obu  35.0000  136.9667     23.96        36         100
# 2          crane  31.3974 -102.3501     24.21        12           1
# 3  blackmans bay -43.0167  147.3167     16.07        52          74
# 4    west island -12.1568   96.8225     29.99        74          40
#
#    Wind Speed Country        Date
# 0        5.00      JP  1683865613
# 1        3.79      JP  1683865386
# 2        1.60      US  1683865614
# 3        2.02      AU  1683865614
# 4        5.66      CC  1683865614

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               nemuro  43.3236  145.5750      6.95        76          15
# 1                  obu  35.0000  136.9667     23.96        36         100
# 2                crane  31.3974 -102.3501     24.21        12           1
# 3        blackmans bay -43.0167  147.3167     16.07        52          74
# 4          west island -12.1568   96.8225     29.99        74          40
#
#          Wind Speed Country        Date
# City_ID
# 0              5.00      JP  1683865613
# 1              3.79      JP  1683865386
# 2              1.60      US  1683865614
# 3              2.02      AU  1683865614
# 4              5.66      CC  1683865614

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], marker = 'o')

# Incorporate the other graph properties
plt.title("City Latitude vs Max Temperature")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], marker = 'o')
# Incorporate the other graph properties
plt.title("City Latitude vs Humidity")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], marker = 'o')

# Incorporate the other graph properties
plt.title("City Latitude vs Cloudiness")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], marker = 'o')

# Incorporate the other graph properties
plt.title("City Latitude vs Wind Speed")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
x_values = city_data_df[]
y_values = city_data_df[]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-40,40),fontsize=15,color="red")
plt.xlabel()
plt.ylabel()
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
#   Cell In[13], line 2
#     x_values = city_data_df[]
#                             ^
# SyntaxError: invalid syntax

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          nemuro  43.3236  145.5750      6.95        76          15
# 1             obu  35.0000  136.9667     23.96        36         100
# 2           crane  31.3974 -102.3501     24.21        12           1
# 5        keflavik  64.0049  -22.5624      6.95       100          75
# 6        enewetak  11.3474  162.3373     27.88        81          90
#
#          Wind Speed Country        Date
# City_ID
# 0              5.00      JP  1683865613
# 1              3.79      JP  1683865386
# 2              1.60      US  1683865614
# 5              5.14      IS  1683865615
# 6              7.13      MH  1683865346

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 3                      blackmans bay -43.0167  147.3167     16.07        52
# 4                        west island -12.1568   96.8225     29.99        74
# 7        edinburgh of the seven seas -37.0676  -12.3116     17.16        87
# 13                      puerto ayora  -0.7393  -90.3518     25.31        98
# 15                         papatowai -46.5619  169.4708     11.24        90
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 3                74        2.02      AU  1683865614
# 4                40        5.66      CC  1683865614
# 7                94       12.53      SH  1683865615
# 13               44        4.47      EC  1683865618
# 15              100        4.24      NZ  1683865618

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,270),fontsize=15,color="red")
plt.xlabel('Northern Latitude')
plt.ylabel('Max Temperature')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:-0.815229815319024

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,295),fontsize=15,color="red")
plt.xlabel('Southern Latitude')
plt.ylabel('Max Temperature')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.6821329218411236

# %% [markdown]
# **Discussion about the linear relationship:** The r-value of 0.682 suggests that there is a low to medium correlation between latitude and max temp in the southern hemisphere

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,45),fontsize=15,color="red")
plt.xlabel('Northern Latitude')
plt.ylabel('Humidity')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.12473151585203454

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,55),fontsize=15,color="red")
plt.xlabel('Southern Latitude')
plt.ylabel('Humidity')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.23076496428612706

# %% [markdown]
# **Discussion about the linear relationship:** The r-value of 0.2307 suggests that there is a low positive correlation between latitude and humidity in the southern hemisphere

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,45),fontsize=15,color="red")
plt.xlabel('Northern Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.032674191861860706

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,55),fontsize=15,color="red")
plt.xlabel('Southern Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:-0.0072150120975155215

# %% [markdown]
# **Discussion about the linear relationship:** the r-value of -0.007 suggests that there is weak negative correlation between latitude and cloudiness in the southern hemisphere

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,8),fontsize=15,color="red")
plt.xlabel('Northern Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.030833849430407723

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,55),fontsize=15,color="red")
plt.xlabel('Southern Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:-0.2303230119732034

# %% [markdown]
# **Discussion about the linear relationship:** the r-value of -0.23 suggests that there is a weak negative correlation between latitude and wind speed in the southern hemisphere
